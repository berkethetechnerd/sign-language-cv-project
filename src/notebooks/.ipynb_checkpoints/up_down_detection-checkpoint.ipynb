# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# OpenCV
import cv2

# Helper libraries
import os

# %%
test_dir = './all_frames/'
test_imgs = ['./all_frames/{}'.format(i) for i in os.listdir(test_dir)]  # get test images

# %%
nrows = 150
ncolumns = 150
channels = 3

# %%
# A function to read and process the images in an acceptable format for our model
def read_and_process_image(list_of_images):
    x = []
    
    for image in list_of_images:
        x.append(cv2.resize(cv2.imread(image, cv2.IMREAD_COLOR), (nrows, ncolumns), interpolation=cv2.INTER_CUBIC)) # Read the image
    
    return x

# %%
from keras import layers
from keras import models
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import img_to_array, load_img
# Out:
# Using TensorFlow backend.

# %%
from keras.models import load_model
model = load_model('./model_keras.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python2.7/site-packages/tensorflow/python/ops/nn_impl.py:180: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %%
from PIL import Image
import numpy as np
import re

test_datagen = ImageDataGenerator(rescale=1./255)
test_result_up = []

for i in range(len(test_imgs)):
    x_test = read_and_process_image(test_imgs[i:i+1])
    x = np.array(x_test)

    for batch in test_datagen.flow(x, batch_size=1):
        if model.predict(batch) < 0.5:
            frame_num = re.findall(r'\d+', test_imgs[i])[0]
            test_result_up.append(int(frame_num))
            
        break
        
    if(i%100==0 or i==(len(test_imgs)) - 1):
        print('{perc}% of process is completed.'.format(perc=i/len(test_imgs)*100))
# Out:
# 0.0% of process is completed.
# 0.244798041616% of process is completed.
# 0.489596083231% of process is completed.
# 0.734394124847% of process is completed.
# 0.979192166463% of process is completed.
# 1.22399020808% of process is completed.
# 1.46878824969% of process is completed.
# 1.71358629131% of process is completed.
# 1.95838433293% of process is completed.
# 2.20318237454% of process is completed.
# 2.44798041616% of process is completed.
# 2.69277845777% of process is completed.
# 2.93757649939% of process is completed.
# 3.182374541% of process is completed.
# 3.42717258262% of process is completed.
# 3.67197062424% of process is completed.
# 3.91676866585% of process is completed.
# 4.16156670747% of process is completed.
# 4.40636474908% of process is completed.
# 4.6511627907% of process is completed.
# 4.89596083231% of process is completed.
# 5.14075887393% of process is completed.
# 5.38555691554% of process is completed.
# 5.63035495716% of process is completed.
# 5.87515299878% of process is completed.
# 6.11995104039% of process is completed.
# 6.36474908201% of process is completed.
# 6.60954712362% of process is completed.
# 6.85434516524% of process is completed.
# 7.09914320685% of process is completed.
# 7.34394124847% of process is completed.
# 7.58873929009% of process is completed.
# 7.8335373317% of process is completed.
# 8.07833537332% of process is completed.
# 8.32313341493% of process is completed.
# 8.56793145655% of process is completed.
# 8.81272949816% of process is completed.
# 9.05752753978% of process is completed.
# 9.3023255814% of process is completed.
# 9.54712362301% of process is completed.
# 9.79192166463% of process is completed.
# 10.0367197062% of process is completed.
# 10.2815177479% of process is completed.
# 10.5263157895% of process is completed.
# 10.7711138311% of process is completed.
# 11.0159118727% of process is completed.
# 11.2607099143% of process is completed.
# 11.5055079559% of process is completed.
# 11.7503059976% of process is completed.
# 11.9951040392% of process is completed.
# 12.2399020808% of process is completed.
# 12.4847001224% of process is completed.
# 12.729498164% of process is completed.
# 12.9742962056% of process is completed.
# 13.2190942472% of process is completed.
# 13.4638922889% of process is completed.
# 13.7086903305% of process is completed.
# 13.9534883721% of process is completed.
# 14.1982864137% of process is completed.
# 14.4430844553% of process is completed.
# 14.6878824969% of process is completed.
# 14.9326805386% of process is completed.
# 15.1774785802% of process is completed.
# 15.4222766218% of process is completed.
# 15.6670746634% of process is completed.
# 15.911872705% of process is completed.
# 16.1566707466% of process is completed.
# 16.4014687882% of process is completed.
# 16.6462668299% of process is completed.
# 16.8910648715% of process is completed.
# 17.1358629131% of process is completed.
# 17.3806609547% of process is completed.
# 17.6254589963% of process is completed.
# 17.8702570379% of process is completed.
# 18.1150550796% of process is completed.
# 18.3598531212% of process is completed.
# 18.6046511628% of process is completed.
# 18.8494492044% of process is completed.
# 19.094247246% of process is completed.
# 19.3390452876% of process is completed.
# 19.5838433293% of process is completed.
# 19.8286413709% of process is completed.
# 20.0734394125% of process is completed.
# 20.3182374541% of process is completed.
# 20.5630354957% of process is completed.
# 20.8078335373% of process is completed.
# 21.0526315789% of process is completed.
# 21.2974296206% of process is completed.
# 21.5422276622% of process is completed.
# 21.7870257038% of process is completed.
# 22.0318237454% of process is completed.
# 22.276621787% of process is completed.
# 22.5214198286% of process is completed.
# 22.7662178703% of process is completed.
# 23.0110159119% of process is completed.
# 23.2558139535% of process is completed.
# 23.5006119951% of process is completed.
# 23.7454100367% of process is completed.
# 23.9902080783% of process is completed.
# 24.23500612% of process is completed.
# 24.4798041616% of process is completed.
# 24.7246022032% of process is completed.
# 24.9694002448% of process is completed.
# 25.2141982864% of process is completed.
# 25.458996328% of process is completed.
# 25.7037943696% of process is completed.
# 25.9485924113% of process is completed.
# 26.1933904529% of process is completed.
# 26.4381884945% of process is completed.
# 26.6829865361% of process is completed.
# 26.9277845777% of process is completed.
# 27.1725826193% of process is completed.
# 27.417380661% of process is completed.
# 27.6621787026% of process is completed.
# 27.9069767442% of process is completed.
# 28.1517747858% of process is completed.
# 28.3965728274% of process is completed.
# 28.641370869% of process is completed.
# 28.8861689106% of process is completed.
# 29.1309669523% of process is completed.
# 29.3757649939% of process is completed.
# 29.6205630355% of process is completed.
# 29.8653610771% of process is completed.
# 30.1101591187% of process is completed.
# 30.3549571603% of process is completed.
# 30.599755202% of process is completed.
# 30.8445532436% of process is completed.
# 31.0893512852% of process is completed.
# 31.3341493268% of process is completed.
# 31.5789473684% of process is completed.
# 31.82374541% of process is completed.
# 32.0685434517% of process is completed.
# 32.3133414933% of process is completed.
# 32.5581395349% of process is completed.
# 32.8029375765% of process is completed.
# 33.0477356181% of process is completed.
# 33.2925336597% of process is completed.
# 33.5373317013% of process is completed.
# 33.782129743% of process is completed.
# 34.0269277846% of process is completed.
# 34.2717258262% of process is completed.
# 34.5165238678% of process is completed.
# 34.7613219094% of process is completed.
# 35.006119951% of process is completed.
# 35.2509179927% of process is completed.
# 35.4957160343% of process is completed.
# 35.7405140759% of process is completed.
# 35.9853121175% of process is completed.
# 36.2301101591% of process is completed.
# 36.4749082007% of process is completed.
# 36.7197062424% of process is completed.
# 36.964504284% of process is completed.
# 37.2093023256% of process is completed.
# 37.4541003672% of process is completed.
# 37.6988984088% of process is completed.
# 37.9436964504% of process is completed.
# 38.188494492% of process is completed.
# 38.4332925337% of process is completed.
# 38.6780905753% of process is completed.
# 38.9228886169% of process is completed.
# 39.1676866585% of process is completed.
# 39.4124847001% of process is completed.
# 39.6572827417% of process is completed.
# 39.9020807834% of process is completed.
# 40.146878825% of process is completed.
# 40.3916768666% of process is completed.
# 40.6364749082% of process is completed.
# 40.8812729498% of process is completed.
# 41.1260709914% of process is completed.
# 41.370869033% of process is completed.
# 41.6156670747% of process is completed.
# 41.8604651163% of process is completed.
# 42.1052631579% of process is completed.
# 42.3500611995% of process is completed.
# 42.5948592411% of process is completed.
# 42.8396572827% of process is completed.
# 43.0844553244% of process is completed.
# 43.329253366% of process is completed.
# 43.5740514076% of process is completed.
# 43.8188494492% of process is completed.
# 44.0636474908% of process is completed.
# 44.3084455324% of process is completed.
# 44.5532435741% of process is completed.
# 44.7980416157% of process is completed.
# 45.0428396573% of process is completed.
# 45.2876376989% of process is completed.
# 45.5324357405% of process is completed.
# 45.7772337821% of process is completed.
# 46.0220318237% of process is completed.
# 46.2668298654% of process is completed.
# 46.511627907% of process is completed.
# 46.7564259486% of process is completed.
# 47.0012239902% of process is completed.
# 47.2460220318% of process is completed.
# 47.4908200734% of process is completed.
# 47.7356181151% of process is completed.
# 47.9804161567% of process is completed.
# 48.2252141983% of process is completed.
# 48.4700122399% of process is completed.
# 48.7148102815% of process is completed.
# 48.9596083231% of process is completed.
# 49.2044063647% of process is completed.
# 49.4492044064% of process is completed.
# 49.694002448% of process is completed.
# 49.9388004896% of process is completed.
# 50.1835985312% of process is completed.
# 50.4283965728% of process is completed.
# 50.6731946144% of process is completed.
# 50.9179926561% of process is completed.
# 51.1627906977% of process is completed.
# 51.4075887393% of process is completed.
# 51.6523867809% of process is completed.
# 51.8971848225% of process is completed.
# 52.1419828641% of process is completed.
# 52.3867809058% of process is completed.
# 52.6315789474% of process is completed.
# 52.876376989% of process is completed.
# 53.1211750306% of process is completed.
# 53.3659730722% of process is completed.
# 53.6107711138% of process is completed.
# 53.8555691554% of process is completed.
# 54.1003671971% of process is completed.
# 54.3451652387% of process is completed.
# 54.5899632803% of process is completed.
# 54.8347613219% of process is completed.
# 55.0795593635% of process is completed.
# 55.3243574051% of process is completed.
# 55.5691554468% of process is completed.
# 55.8139534884% of process is completed.
# 56.05875153% of process is completed.
# 56.3035495716% of process is completed.
# 56.5483476132% of process is completed.
# 56.7931456548% of process is completed.
# 57.0379436965% of process is completed.
# 57.2827417381% of process is completed.
# 57.5275397797% of process is completed.
# 57.7723378213% of process is completed.
# 58.0171358629% of process is completed.
# 58.2619339045% of process is completed.
# 58.5067319461% of process is completed.
# 58.7515299878% of process is completed.
# 58.9963280294% of process is completed.
# 59.241126071% of process is completed.
# 59.4859241126% of process is completed.
# 59.7307221542% of process is completed.
# 59.9755201958% of process is completed.
# 60.2203182375% of process is completed.
# 60.4651162791% of process is completed.
# 60.7099143207% of process is completed.
# 60.9547123623% of process is completed.
# 61.1995104039% of process is completed.
# 61.4443084455% of process is completed.
# 61.6891064871% of process is completed.
# 61.9339045288% of process is completed.
# 62.1787025704% of process is completed.
# 62.423500612% of process is completed.
# 62.6682986536% of process is completed.
# 62.9130966952% of process is completed.
# 63.1578947368% of process is completed.
# 63.4026927785% of process is completed.
# 63.6474908201% of process is completed.
# 63.8922888617% of process is completed.
# 64.1370869033% of process is completed.
# 64.3818849449% of process is completed.
# 64.6266829865% of process is completed.
# 64.8714810282% of process is completed.
# 65.1162790698% of process is completed.
# 65.3610771114% of process is completed.
# 65.605875153% of process is completed.
# 65.8506731946% of process is completed.
# 66.0954712362% of process is completed.
# 66.3402692778% of process is completed.
# 66.5850673195% of process is completed.
# 66.8298653611% of process is completed.
# 67.0746634027% of process is completed.
# 67.3194614443% of process is completed.
# 67.5642594859% of process is completed.
# 67.8090575275% of process is completed.
# 68.0538555692% of process is completed.
# 68.2986536108% of process is completed.
# 68.5434516524% of process is completed.
# 68.788249694% of process is completed.
# 69.0330477356% of process is completed.
# 69.2778457772% of process is completed.
# 69.5226438188% of process is completed.
# 69.7674418605% of process is completed.
# 70.0122399021% of process is completed.
# 70.2570379437% of process is completed.
# 70.5018359853% of process is completed.
# 70.7466340269% of process is completed.
# 70.9914320685% of process is completed.
# 71.2362301102% of process is completed.
# 71.4810281518% of process is completed.
# 71.7258261934% of process is completed.
# 71.970624235% of process is completed.
# 72.2154222766% of process is completed.
# 72.4602203182% of process is completed.
# 72.7050183599% of process is completed.
# 72.9498164015% of process is completed.
# 73.1946144431% of process is completed.
# 73.4394124847% of process is completed.
# 73.6842105263% of process is completed.
# 73.9290085679% of process is completed.
# 74.1738066095% of process is completed.
# 74.4186046512% of process is completed.
# 74.6634026928% of process is completed.
# 74.9082007344% of process is completed.
# 75.152998776% of process is completed.
# 75.3977968176% of process is completed.
# 75.6425948592% of process is completed.
# 75.8873929009% of process is completed.
# 76.1321909425% of process is completed.
# 76.3769889841% of process is completed.
# 76.6217870257% of process is completed.
# 76.8665850673% of process is completed.
# 77.1113831089% of process is completed.
# 77.3561811506% of process is completed.
# 77.6009791922% of process is completed.
# 77.8457772338% of process is completed.
# 78.0905752754% of process is completed.
# 78.335373317% of process is completed.
# 78.5801713586% of process is completed.
# 78.8249694002% of process is completed.
# 79.0697674419% of process is completed.
# 79.3145654835% of process is completed.
# 79.5593635251% of process is completed.
# 79.8041615667% of process is completed.
# 80.0489596083% of process is completed.
# 80.2937576499% of process is completed.
# 80.5385556916% of process is completed.
# 80.7833537332% of process is completed.
# 81.0281517748% of process is completed.
# 81.2729498164% of process is completed.
# 81.517747858% of process is completed.
# 81.7625458996% of process is completed.
# 82.0073439412% of process is completed.
# 82.2521419829% of process is completed.
# 82.4969400245% of process is completed.
# 82.7417380661% of process is completed.
# 82.9865361077% of process is completed.
# 83.2313341493% of process is completed.
# 83.4761321909% of process is completed.
# 83.7209302326% of process is completed.
# 83.9657282742% of process is completed.
# 84.2105263158% of process is completed.
# 84.4553243574% of process is completed.
# 84.700122399% of process is completed.
# 84.9449204406% of process is completed.
# 85.1897184823% of process is completed.
# 85.4345165239% of process is completed.
# 85.6793145655% of process is completed.
# 85.9241126071% of process is completed.
# 86.1689106487% of process is completed.
# 86.4137086903% of process is completed.
# 86.6585067319% of process is completed.
# 86.9033047736% of process is completed.
# 87.1481028152% of process is completed.
# 87.3929008568% of process is completed.
# 87.6376988984% of process is completed.
# 87.88249694% of process is completed.
# 88.1272949816% of process is completed.
# 88.3720930233% of process is completed.
# 88.6168910649% of process is completed.
# 88.8616891065% of process is completed.
# 89.1064871481% of process is completed.
# 89.3512851897% of process is completed.
# 89.5960832313% of process is completed.
# 89.8408812729% of process is completed.
# 90.0856793146% of process is completed.
# 90.3304773562% of process is completed.
# 90.5752753978% of process is completed.
# 90.8200734394% of process is completed.
# 91.064871481% of process is completed.
# 91.3096695226% of process is completed.
# 91.5544675643% of process is completed.
# 91.7992656059% of process is completed.
# 92.0440636475% of process is completed.
# 92.2888616891% of process is completed.
# 92.5336597307% of process is completed.
# 92.7784577723% of process is completed.
# 93.023255814% of process is completed.
# 93.2680538556% of process is completed.
# 93.5128518972% of process is completed.
# 93.7576499388% of process is completed.
# 94.0024479804% of process is completed.
# 94.247246022% of process is completed.
# 94.4920440636% of process is completed.
# 94.7368421053% of process is completed.
# 94.9816401469% of process is completed.
# 95.2264381885% of process is completed.
# 95.4712362301% of process is completed.
# 95.7160342717% of process is completed.
# 95.9608323133% of process is completed.
# 96.205630355% of process is completed.
# 96.4504283966% of process is completed.
# 96.6952264382% of process is completed.
# 96.9400244798% of process is completed.
# 97.1848225214% of process is completed.
# 97.429620563% of process is completed.
# 97.6744186047% of process is completed.
# 97.9192166463% of process is completed.
# 98.1640146879% of process is completed.
# 98.4088127295% of process is completed.
# 98.6536107711% of process is completed.
# 98.8984088127% of process is completed.
# 99.1432068543% of process is completed.
# 99.388004896% of process is completed.
# 99.6328029376% of process is completed.
# 99.8776009792% of process is completed.
# 99.9975520196% of process is completed.

# %%
test_result_up.sort()

# %%
segmentation = []
frame_counting = False

frame_batch = []
for frame in test_result_up:
    if not frame_counting:
        frame_counting = True
        frame_batch.append(frame)
        
    else:
        diff_last = frame - frame_batch[len(frame_batch) - 1]
        
        if diff_last > 5:
            segmentation.append(frame_batch)
            frame_batch = []
            frame_batch.append(frame)
            
        else:
            frame_batch.append(frame)

# %%
import shutil

video_output_dir = './segmentation_output/'
if os.path.exists(video_output_dir):
    shutil.rmtree(video_output_dir, ignore_errors = True)
    
os.mkdir(video_output_dir)

for segment in segmentation:
    frame_arr = []
    
    for frame in segment:
        frame_file = test_dir + 'frame' + str(frame) + '.jpg'
        frame_img = cv2.imread(frame_file)
        frame_arr.append(frame_img)
        
    height, width, layers = frame_arr[0].shape
    fourcc = cv2.VideoWriter_fourcc(*'mpeg')
    size = (width, height)
    fps = 30
    
    video_path = video_output_dir + 'video_' + str(segment[0]) + '_' + str(segment[len(frame_arr) - 1]) + '.mp4'
    
    cap = cv2.VideoWriter(video_path, fourcc, fps, size)
    for i in range(len(frame_arr)):
        cap.write(frame_arr[i])
        
    cap.release()
